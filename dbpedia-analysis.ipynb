# %% [markdown]
# ## Analysis and comparison of chemical data in Wikipedia and Wikidata
#
# This notebook is intended for retrieving and comparing chemical compound data in Wikipedia and Wikidata

# %%
import requests
import pandas as pd
import json
import os

# query dbpedia for chemistry info

query = '''
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX : <http://dbpedia.org/resource/>
PREFIX dbpedia2: <http://dbpedia.org/property/>
PREFIX dbpedia: <http://dbpedia.org/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX wikidata: <http://www.wikidata.org/entity/>
PREFIX dbp: <http://dbpedia.org/property/>
PREFIX dbo: <http://dbpedia.org/ontology/>

SELECT DISTINCT * WHERE {{
 {{?c rdf:type dbo:ChemicalSubstance .}} UNION
 {{?c rdf:type dbo:ChemicalCompound .}}
 
 OPTIONAL {{?c rdfs:label ?label FILTER(LANG(?label) = 'en').}}
 OPTIONAL {{?c dbp:stdinchikey ?stdinchikey.}}
 OPTIONAL {{?c dbp:stdinchi ?stdinchi .}}
 OPTIONAL {{?c dbp:smiles ?smiles .}}
 OPTIONAL {{?c dbo:fdaUniiCode ?fdaUniiCode .}}
 OPTIONAL {{?c dbp:chembl ?chembl .}} 
 OPTIONAL {{?c owl:sameAs ?wikidata . FILTER(STRSTARTS(STR(?wikidata), 
                                    'http://wikidata.dbpedia.org/resource/'))}}
 OPTIONAL {{?c dbp:routesOfAdministration ?routesOfAdministration .}} 
 OPTIONAL {{?c dbp:pubchem ?pubchem .}} 
 OPTIONAL {{?c dbp:casNumber ?casNumber .}}
 OPTIONAL {{?c dbp:kegg ?kegg .}}
 OPTIONAL {{?c dbp:iupharLigand ?iupharLigand .}}
 OPTIONAL {{?c dbp:chemspiderid ?chemspiderid .}} 
 OPTIONAL {{?c dbp:synonyms ?synonyms .}}  
 OPTIONAL {{?c dbp:atcPrefix ?atcPrefix .}}
 OPTIONAL {{?c dbp:atcSuffix ?atcSuffix .}}
 

 
}}
LIMIT 100000 OFFSET {}
'''

# headers not required for this endpoint
headers = {
    'content-type': 'application/sparql-results+json',
    'charset': 'utf-8',
    'Accept': 'application/sparql-results+json'
}

url = 'http://dbpedia.org/sparql'

tmp_data = {}
for c in [0, 10000]:
    params = {
        'query': query.format(c),
        'format': 'json',
        'maxrows': '100000',
        'timeout': '60000'
    }
    r = requests.get(url, params=params)
    if tmp_data == {}:    
        tmp_data.update(r.json())
    else:
        tmp_data['results']['bindings'].extend(r.json()['results']['bindings'])
    print(len(tmp_data['results']['bindings']))
    

if not os.path.exists('./dbpedia_data'):
    os.makedirs('./dbpedia_data')
    
with open('./dbpedia_data/dbpedia_query_results.json', 'w') as of:
    json.dump(tmp_data, of)
# Out:
# 10000
# 18001

# %%
columns = tmp_data['head']['vars']
columns
# Out:
# ['c',
#  'label',
#  'stdinchikey',
#  'stdinchi',
#  'smiles',
#  'fdaUniiCode',
#  'chembl',
#  'wikidata',
#  'routesOfAdministration',
#  'pubchem',
#  'casNumber',
#  'kegg',
#  'iupharLigand',
#  'chemspiderid',
#  'synonyms',
#  'atcPrefix',
#  'atcSuffix']

# %%
dbpedia_chem_data = pd.DataFrame(columns=columns)
# dbpedia_chem_data.set_index

def get_all_single_compound_data(cmpnd):
    for x in tmp_data['results']['bindings']:
        if x['c']['value'] == cmpnd:
            yield {k: v['value'] for k, v in x.items() if k != 'c'}

count = 0
for y in tmp_data['results']['bindings']:
    cmpnd = y['c']['value']
    #print(cmpnd)
    if cmpnd in dbpedia_chem_data['c'].values:
        continue
                       
    dbpedia_chem_data.loc[count, 'c'] = cmpnd

    for zz in get_all_single_compound_data(cmpnd):
        for col, value in zz.items():
            if pd.notnull(dbpedia_chem_data.loc[count, col]):
                td = set(dbpedia_chem_data.loc[count, col].split('|'))
                td.add(value)
                dbpedia_chem_data.loc[count, col] = '|'.join(td)
            else:
                dbpedia_chem_data.loc[count, col] = value
                
    count += 1
    if count % 1000 == 0:
        print(count)
        #print(dbpedia_chem_data[count-10:count])
#         break
            
dbpedia_chem_data
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
#                                                        c  \
# 0               http://dbpedia.org/resource/Frovatriptan
# 1         http://dbpedia.org/resource/Methylprednisolone
# 2                   http://dbpedia.org/resource/Neomycin
# 3                 http://dbpedia.org/resource/Cetirizine
# 4                  http://dbpedia.org/resource/Imiquimod
# 5               http://dbpedia.org/resource/Bicalutamide
# 6                  http://dbpedia.org/resource/Goserelin
# 7       http://dbpedia.org/resource/Ursodeoxycholic_acid
# 8                  http://dbpedia.org/resource/Foscarnet
# 9      http://dbpedia.org/resource/Norepinephrine_(me...
# 10        http://dbpedia.org/resource/Diethylstilbestrol
# 11               http://dbpedia.org/resource/Finasteride
# 12                http://dbpedia.org/resource/Imipramine
# 13              http://dbpedia.org/resource/Methotrexate
# 14                  http://dbpedia.org/resource/Oxytocin
# 15              http://dbpedia.org/resource/Pantoprazole
# 16                  http://dbpedia.org/resource/Diazepam
# 17                http://dbpedia.org/resource/Fosinopril
# 18               http://dbpedia.org/resource/Hydralazine
# 19               http://dbpedia.org/resource/Doxorubicin
# 20                http://dbpedia.org/resource/Nifedipine
# 21              http://dbpedia.org/resource/Perphenazine
# 22               http://dbpedia.org/resource/Terbutaline
# 23                  http://dbpedia.org/resource/Procaine
# 24               http://dbpedia.org/resource/Domperidone
# 25               http://dbpedia.org/resource/Rizatriptan
# 26                 http://dbpedia.org/resource/Adapalene
# 27           http://dbpedia.org/resource/Alendronic_acid
# 28                http://dbpedia.org/resource/Bumetanide
# 29              http://dbpedia.org/resource/Fenfluramine
# ...                                                  ...
# 17128              http://dbpedia.org/resource/Advantame
# 17129          http://dbpedia.org/resource/Basic_Black_2
# 17130            http://dbpedia.org/resource/Birnbaumins
# 17131     http://dbpedia.org/resource/Diallyl_trisulfide
# 17132       http://dbpedia.org/resource/Ferrous_tartrate
# 17133               http://dbpedia.org/resource/Isoxaben
# 17134               http://dbpedia.org/resource/Kuratite
# 17135  http://dbpedia.org/resource/Magnesium_orthosil...
# 17136           http://dbpedia.org/resource/Ochnaflavone
# 17137              http://dbpedia.org/resource/Putnisite
# 17138            http://dbpedia.org/resource/Retronecine
# 17139     http://dbpedia.org/resource/Tetramesityldiiron
# 17140            http://dbpedia.org/resource/Vat_Green_1
# 17141            http://dbpedia.org/resource/Vat_Green_9
# 17142           http://dbpedia.org/resource/Vat_Yellow_1
# 17143              http://dbpedia.org/resource/Vicianose
# 17144   http://dbpedia.org/resource/Lithium_metasilicate
# 17145      http://dbpedia.org/resource/Cyclohexene_oxide
# 17146                 http://dbpedia.org/resource/BIT225
# 17147  http://dbpedia.org/resource/Chlorodiisopropylp...
# 17148                    http://dbpedia.org/resource/E1R
# 17149  http://dbpedia.org/resource/Gamma-Hydroxybutyr...
# 17150         http://dbpedia.org/resource/Homocitrulline
# 17151           http://dbpedia.org/resource/Homolycorine
# 17152             http://dbpedia.org/resource/Navitoclax
# 17153             http://dbpedia.org/resource/Verbenalin
# 17154      http://dbpedia.org/resource/Zirconium_nitrate
# 17155  http://dbpedia.org/resource/N-Fluoropyridinium...
# 17156   http://dbpedia.org/resource/Allyl_glycidyl_ether
# 17157    http://dbpedia.org/resource/Vanadyl_perchlorate
#
#                              label                  stdinchikey stdinchi  \
# 0                     Frovatriptan  XPSQPHWEGNHMSK-SECBINFHSA-N        1
# 1               Methylprednisolone  VHRSUDSXCMQTMA-PJHHCJLFSA-N        1
# 2                         Neomycin  PGBHMTALBVVCIT-DPNHOFNISA-N        1
# 3                       Cetirizine  ZKLPARSLTMPFCP-UHFFFAOYSA-N        1
# 4                        Imiquimod  DOUYETYNHWVLEO-UHFFFAOYSA-N        1
# 5                     Bicalutamide  LKJPYSCBVHEWIU-UHFFFAOYSA-N        1
# 6                        Goserelin  BLCLNMBMMGCOAS-URPVMXJPSA-N        1
# 7             Ursodeoxycholic acid  RUDATBOHQWOJDD-UZVSRGJWSA-N        1
# 8                        Foscarnet  ZJAOAACCNHFJAH-UHFFFAOYSA-N        1
# 9      Norepinephrine (medication)  SFLSHLFXELFNJZ-QMMMGPOBSA-N        1
# 10              Diethylstilbestrol  RGLYKWWBQGJZGM-ISLYRVAYSA-N        1
# 11                     Finasteride  DBEPLOCGEIEOCV-WSBQPABSSA-N        1
# 12                      Imipramine  BCGWQEUPMDMJNV-UHFFFAOYSA-N        1
# 13                    Methotrexate  FBOZXECLQNJBKD-ZDUSSCGKSA-N        1
# 14                        Oxytocin  XNOPRXBHLZRZKH-DSZYJQQASA-N        1
# 15                    Pantoprazole  IQPSEEYGBUAQFF-UHFFFAOYSA-N        1
# 16                        Diazepam  AAOVKJBEBIDNHE-UHFFFAOYSA-N        1
# 17                      Fosinopril  BIDNLKIUORFRQP-YYTCENNOSA-N        1
# 18                     Hydralazine  RPTUSVTUFVMDQK-UHFFFAOYSA-N        1
# 19                     Doxorubicin  AOJJSUZBOXZQNB-TZSSRYMLSA-N        1
# 20                      Nifedipine  HYIMSNHJOBLJNT-UHFFFAOYSA-N        1
# 21                    Perphenazine  RGCVKNLCSQQDEP-UHFFFAOYSA-N        1
# 22                     Terbutaline  XWTYSIMOBUGWOL-UHFFFAOYSA-N        1
# 23                        Procaine  MFDFERRIHVXMIY-UHFFFAOYSA-N        1
# 24                     Domperidone  FGXWKSZFVQUSTL-UHFFFAOYSA-N        1
# 25                     Rizatriptan  ULFRLSNUDGIQQP-UHFFFAOYSA-N        1
# 26                       Adapalene  LZCDAPDGXCYOEH-UHFFFAOYSA-N        1
# 27                 Alendronic acid  OGSPWJRAVKPPFI-UHFFFAOYSA-N        1
# 28                      Bumetanide  MAEIEVLCKWDQJH-UHFFFAOYSA-N        1
# 29                    Fenfluramine  DBGIVFWFUFKIQN-UHFFFAOYSA-N        1
# ...                            ...                          ...      ...
# 17128                    Advantame                          NaN      NaN
# 17129                Basic Black 2                          NaN      NaN
# 17130                  Birnbaumins                          NaN      NaN
# 17131           Diallyl trisulfide                          NaN      NaN
# 17132             Ferrous tartrate                          NaN      NaN
# 17133                     Isoxaben                          NaN      NaN
# 17134                     Kuratite                          NaN      NaN
# 17135      Magnesium orthosilicate                          NaN      NaN
# 17136                 Ochnaflavone                          NaN      NaN
# 17137                    Putnisite                          NaN      NaN
# 17138                  Retronecine                          NaN      NaN
# 17139           Tetramesityldiiron                          NaN      NaN
# 17140                  Vat Green 1                          NaN      NaN
# 17141                  Vat Green 9                          NaN      NaN
# 17142                 Vat Yellow 1                          NaN      NaN
# 17143                    Vicianose                          NaN      NaN
# 17144         Lithium metasilicate                          NaN      NaN
# 17145            Cyclohexene oxide                          NaN      NaN
# 17146                       BIT225                          NaN      NaN
# 17147   Chlorodiisopropylphosphine                          NaN      NaN
# 17148                          E1R                          NaN      NaN
# 17149   Gamma-Hydroxybutyraldehyde                          NaN      NaN
# 17150               Homocitrulline                          NaN      NaN
# 17151                 Homolycorine                          NaN      NaN
# 17152                   Navitoclax                          NaN      NaN
# 17153                   Verbenalin                          NaN      NaN
# 17154            Zirconium nitrate                          NaN      NaN
# 17155  N-Fluoropyridinium triflate                          NaN      NaN
# 17156         Allyl glycidyl ether                          NaN      NaN
# 17157          Vanadyl perchlorate                          NaN      NaN
#
#                                                   smiles fdaUniiCode   chembl  \
# 0                                           O=Cc3ccc1cc3  H82Q2D5WA7     1279
# 1                                       O=C\1\C=C/[C@]4C  X4W7ZR7023      650
# 2                                       O[C@H]4O[C@@H]CN  I16QD7X297   449118
# 3                                    Clc1cccCN3CCNCCOCCO  YO7261ME24     1000
# 4                                       n3c1ccccc1c2cc3N  P1QW714R7M     1282
# 5                                         O=CCCSc2ccccc2  A0Z3NAU9DP    63560
# 6                     CCC[C@H]CN[C@@H]CN1CCC[C@H]1CNNC=O  0F65R8P09N  1201247
# 7                                            O=CCC[C@H]C  724L30Y2QR     1551
# 8                                                  O=CPO  8C5OQ81LWT      666
# 9                                         Oc1ccc[C@@H]CN  X4W3ENH1CV     1437
# 10                                             Oc2ccccc2  731DCA35BT      411
# 11                                      O=C[C@@H]2[C@]1C  57GNO57U7G      710
# 12                                    c1cc3cCCc2cN3CCCNC  OGG85SX4E4       11
# 13                                                  O=CO  YL5FZ2Y5U1    34259
# 14     CC[C@H][C@@H]1NC[C@H]NC[C@@H]CSSC[C@H]CN3CCC[C...  1JQS135EYN   395429
# 15                                          FCOc3cc1ccc3  D8TST4O562     1502
# 16                                        CN1C2=CC=CC=C2  Q3JTX2Q7TU       12
# 17                                  O=CN2C[C@@H]C3CCCCC3  R43D2573WO  3039598
# 18                                                n2ncNN  26NAK24LS8   276832
# 19                                         C[C@H]1[C@H]O  80168379AG    53463
# 20                                             O=C\C1=CC  I9ZF7L6G2L      193
# 21                                   Clc2cc1NCCCN4CCNCC4  FTA7XXY4EZ      567
# 22                                            Oc1ccCCNCC  N8ONU3L3PG     1760
# 23                                           O=Cc1ccccc1  4Z8Y51M438      569
# 24                                     Clc1cc2cNC5CCNCC5  5587267Z69   219916
# 25                                   n1cnCc2cc3cncc3CCNC  WR978S7QHH      905
# 26                             O=Cc2ccc1ccc3ccC46CC5CCC6  1L4806J2QF     1265
# 27                                                O=PCPO  X1J18R4W8P      870
# 28                                                  O=SN  0Y2S3XUQ5H     1072
# 29                                                   FCF  2DS058H2CF    87493
# ...                                                  ...         ...      ...
# 17128                                                NaN         NaN      NaN
# 17129                                                NaN         NaN      NaN
# 17130                                                NaN         NaN      NaN
# 17131                                                NaN         NaN      NaN
# 17132                                                NaN         NaN      NaN
# 17133                                                NaN         NaN      NaN
# 17134                                                NaN         NaN      NaN
# 17135                                                NaN         NaN      NaN
# 17136                                                NaN         NaN      NaN
# 17137                                                NaN         NaN      NaN
# 17138                                                NaN         NaN      NaN
# 17139                                                NaN         NaN      NaN
# 17140                                                NaN         NaN      NaN
# 17141                                                NaN         NaN      NaN
# 17142                                                NaN         NaN      NaN
# 17143                                                NaN         NaN      NaN
# 17144                                                NaN         NaN      NaN
# 17145                                                NaN         NaN      NaN
# 17146                                                NaN         NaN      NaN
# 17147                                                NaN         NaN      NaN
# 17148                                                NaN         NaN      NaN
# 17149                                                NaN         NaN      NaN
# 17150                                                NaN         NaN      NaN
# 17151                                                NaN         NaN      NaN
# 17152                                                NaN         NaN      NaN
# 17153                                                NaN         NaN      NaN
# 17154                                                NaN         NaN      NaN
# 17155                                                NaN         NaN      NaN
# 17156                                                NaN         NaN      NaN
# 17157                                                NaN         NaN      NaN
#
#                                              wikidata  \
# 0        http://wikidata.dbpedia.org/resource/Q410195
# 1        http://wikidata.dbpedia.org/resource/Q417222
# 2        http://wikidata.dbpedia.org/resource/Q423098
# 3        http://wikidata.dbpedia.org/resource/Q423075
# 4        http://wikidata.dbpedia.org/resource/Q423417
# 5       http://wikidata.dbpedia.org/resource/Q1988832
# 6       http://wikidata.dbpedia.org/resource/Q1992653
# 7        http://wikidata.dbpedia.org/resource/Q241374
# 8        http://wikidata.dbpedia.org/resource/Q420387
# 9                                                 NaN
# 10       http://wikidata.dbpedia.org/resource/Q423989
# 11       http://wikidata.dbpedia.org/resource/Q424167
# 12        http://wikidata.dbpedia.org/resource/Q58396
# 13       http://wikidata.dbpedia.org/resource/Q422232
# 14       http://wikidata.dbpedia.org/resource/Q169960
# 15       http://wikidata.dbpedia.org/resource/Q286846
# 16       http://wikidata.dbpedia.org/resource/Q210402
# 17       http://wikidata.dbpedia.org/resource/Q425293
# 18       http://wikidata.dbpedia.org/resource/Q419987
# 19        http://wikidata.dbpedia.org/resource/Q18936
# 20        http://wikidata.dbpedia.org/resource/Q39111
# 21       http://wikidata.dbpedia.org/resource/Q423520
# 22       http://wikidata.dbpedia.org/resource/Q424340
# 23       http://wikidata.dbpedia.org/resource/Q423741
# 24       http://wikidata.dbpedia.org/resource/Q424238
# 25       http://wikidata.dbpedia.org/resource/Q212171
# 26       http://wikidata.dbpedia.org/resource/Q352348
# 27       http://wikidata.dbpedia.org/resource/Q420057
# 28       http://wikidata.dbpedia.org/resource/Q275926
# 29       http://wikidata.dbpedia.org/resource/Q418928
# ...                                               ...
# 17128  http://wikidata.dbpedia.org/resource/Q16886625
# 17129  http://wikidata.dbpedia.org/resource/Q16838387
# 17130  http://wikidata.dbpedia.org/resource/Q16966708
# 17131  http://wikidata.dbpedia.org/resource/Q17148332
# 17132  http://wikidata.dbpedia.org/resource/Q18207095
# 17133   http://wikidata.dbpedia.org/resource/Q2677285
# 17134  http://wikidata.dbpedia.org/resource/Q16062426
# 17135  http://wikidata.dbpedia.org/resource/Q17093981
# 17136  http://wikidata.dbpedia.org/resource/Q17099497
# 17137  http://wikidata.dbpedia.org/resource/Q16605091
# 17138   http://wikidata.dbpedia.org/resource/Q3933789
# 17139  http://wikidata.dbpedia.org/resource/Q17121628
# 17140  http://wikidata.dbpedia.org/resource/Q17047307
# 17141  http://wikidata.dbpedia.org/resource/Q17027466
# 17142  http://wikidata.dbpedia.org/resource/Q16999997
# 17143  http://wikidata.dbpedia.org/resource/Q18358922
# 17144  http://wikidata.dbpedia.org/resource/Q16830195
# 17145   http://wikidata.dbpedia.org/resource/Q2750068
# 17146  http://wikidata.dbpedia.org/resource/Q18355839
# 17147  http://wikidata.dbpedia.org/resource/Q18387387
# 17148  http://wikidata.dbpedia.org/resource/Q18388898
# 17149  http://wikidata.dbpedia.org/resource/Q19597550
# 17150  http://wikidata.dbpedia.org/resource/Q18207833
# 17151  http://wikidata.dbpedia.org/resource/Q18349931
# 17152  http://wikidata.dbpedia.org/resource/Q18002993
# 17153  http://wikidata.dbpedia.org/resource/Q18559312
# 17154   http://wikidata.dbpedia.org/resource/Q4321598
# 17155  http://wikidata.dbpedia.org/resource/Q19904191
# 17156   http://wikidata.dbpedia.org/resource/Q2467070
# 17157                                             NaN
#
#                                   routesOfAdministration  pubchem   casNumber  \
# 0                      http://dbpedia.org/resource/Mouth    77992      158930
# 1             IV, IM, IV Infusion, Oral, Rectal, Topical     6741          83
# 2      http://dbpedia.org/resource/Mouth|http://dbped...     8378  1404-04-02
# 3                                                   Oral     2678       83881
# 4         http://dbpedia.org/resource/Topical_medication    57469       99011
# 5                                                   Oral     2375       90357
# 6         http://dbpedia.org/resource/Implant_(medicine)  5311128       65807
# 7                                                   oral    31401         128
# 8        http://dbpedia.org/resource/Intravenous_therapy     3415       63585
# 9                                            Intravenous   439260          51
# 10                                              IV, oral   448537          56
# 11                                                  Oral    57363       98319
# 12                                                  Oral     3696          50
# 13     http://dbpedia.org/resource/Intravenous_therap...   126941          59
# 14     http://dbpedia.org/resource/Intravenous_therap...   439302          50
# 15                                  Oral and intravenous     4679      102625
# 16                             Oral, IM, IV, suppository     3016         439
# 17                                                  oral    55891       98048
# 18                                     Oral, intravenous     3637          86
# 19                             Intravenous, intravesical    31703       23214
# 20                                         Oral, Topical     4485       21829
# 21                                           Oral and IM     4748          58
# 22                                     SQ, Oral, Inhaled     5403       23031
# 23           http://dbpedia.org/resource/Wikt:Parenteral     4914          59
# 24                             Oral, intravenous, rectal     3151       57808
# 25                                                  Oral     5078      145202
# 26        http://dbpedia.org/resource/Topical_medication    60164      106685
# 27                                                  Oral     2088      121268
# 28                      oral, intravenous, intramuscular     2471       28395
# 29                                                  Oral     3337         458
# ...                                                  ...      ...         ...
# 17128                                                NaN      NaN         NaN
# 17129                                                NaN      NaN         NaN
# 17130                                                NaN      NaN         NaN
# 17131                                                NaN      NaN         NaN
# 17132                                                NaN      NaN         NaN
# 17133                                                NaN      NaN         NaN
# 17134                                                NaN      NaN         NaN
# 17135                                                NaN      NaN         NaN
# 17136                                                NaN      NaN         NaN
# 17137                                                NaN      NaN         NaN
# 17138                                                NaN      NaN         NaN
# 17139                                                NaN      NaN         NaN
# 17140                                                NaN      NaN         NaN
# 17141                                                NaN      NaN         NaN
# 17142                                                NaN      NaN         NaN
# 17143                                                NaN      NaN         NaN
# 17144                                                NaN      NaN         NaN
# 17145                                                NaN      NaN         NaN
# 17146                                                NaN      NaN         NaN
# 17147                                                NaN      NaN         NaN
# 17148                                                NaN      NaN         NaN
# 17149                                                NaN      NaN         NaN
# 17150                                                NaN      NaN         NaN
# 17151                                                NaN      NaN         NaN
# 17152                                                NaN      NaN         NaN
# 17153                                                NaN      NaN         NaN
# 17154                                                NaN      NaN         NaN
# 17155                                                NaN      NaN         NaN
# 17156                                                NaN      NaN         NaN
# 17157                                                NaN      NaN         NaN
#
#          kegg iupharLigand chemspiderid  \
# 0      D07997         7191        70378
# 1      D00407         7088         6485
# 2      D08260          709         8075
# 3      D07662         1222         2577
# 4      D02500         5003        51809
# 5      D00961         2863         2284
# 6      D04405         3879      4470656
# 7      D00734         7104        29131
# 8      6456.0         5497         3297
# 9      D00076          505       388394
# 10     D00577         2801       395306
# 11     D00321         6818        51714
# 12     D08070          357         3568
# 13     D00142         4815       112728
# 14     D00089         2174       388434
# 15     D05353         7260         4517
# 16     D00293         3364         2908
# 17     D07992         6456     10482016
# 18     D08044         7326         3511
# 19     D03899         7069        29400
# 20     D00437         2514         4330
# 21     D00503          209         4586
# 22     D08570          560         5210
# 23     D08422         4291         4745
# 24     D01745          965         3039
# 25     D00675           51         4900
# 26     D01112         5429        54244
# 27     D07119         3141         2004
# 28     D00247         4837         2377
# 29     D07945         4613         3220
# ...       ...          ...          ...
# 17128     NaN          NaN          NaN
# 17129     NaN          NaN          NaN
# 17130     NaN          NaN          NaN
# 17131     NaN          NaN          NaN
# 17132     NaN          NaN          NaN
# 17133     NaN          NaN          NaN
# 17134     NaN          NaN          NaN
# 17135     NaN          NaN          NaN
# 17136     NaN          NaN          NaN
# 17137     NaN          NaN          NaN
# 17138     NaN          NaN          NaN
# 17139     NaN          NaN          NaN
# 17140     NaN          NaN          NaN
# 17141     NaN          NaN          NaN
# 17142     NaN          NaN          NaN
# 17143     NaN          NaN          NaN
# 17144     NaN          NaN          NaN
# 17145     NaN          NaN          NaN
# 17146     NaN          NaN          NaN
# 17147     NaN          NaN          NaN
# 17148     NaN          NaN          NaN
# 17149     NaN          NaN          NaN
# 17150     NaN          NaN          NaN
# 17151     NaN          NaN          NaN
# 17152     NaN          NaN          NaN
# 17153     NaN          NaN          NaN
# 17154     NaN          NaN          NaN
# 17155     NaN          NaN          NaN
# 17156     NaN          NaN          NaN
# 17157     NaN          NaN          NaN
#
#                                                 synonyms atcPrefix atcSuffix
# 0                                                   6|-6       N02      CC07
# 1                                                -111721       D07      AA01
# 2                                             Framycetin       A01      AB08
# 3      Alerid, Alatrol, Alzene, Cetirizina, Cetirin, ...       R06      AE07
# 4                                                      1       D06      BB10
# 5                                             ICI-176334       L02      BB03
# 6                                      D-Ser6Azgly10LHRH       L02      AE03
# 7      ursodeoxycholic acid, Actigall, Ursosan, Urso,...       A05      AA02
# 8      (phosphonomethanoic acid, dihydroxyphosphineca...       J05      AD01
# 9      l-1--2-aminoethanol|--Norepinephrine|Noradrena...       1.0      CA03
# 10                                                   NaN       G03      CB02
# 11                                                   NaN       G04      CB01
# 12                                                   NaN       N06      AA02
# 13                                                   NaN       L01      BA01
# 14                                                   NaN       H01      BB02
# 15                                                   NaN       A02      BC02
# 16                                                   NaN       N05      BA01
# 17                                                   NaN       9.0      AA09
# 18                                                   NaN       2.0      DB02
# 19                                                   NaN       L01      DB01
# 20                                                   NaN       8.0      CA05
# 21                                                   NaN       N05      AB03
# 22                                                   NaN       R03      AC03
# 23                                                   NaN       N01      BA02
# 24                                                   NaN       A03      FA03
# 25                                                   NaN       N02      CC04
# 26                                                   NaN       D10      AD03
# 27                                                   NaN       M05      BA04
# 28                                                   NaN       3.0      CA02
# 29                                                   NaN       A08      AA02
# ...                                                  ...       ...       ...
# 17128                                                NaN       NaN       NaN
# 17129                                                NaN       NaN       NaN
# 17130                                                NaN       NaN       NaN
# 17131                                                NaN       NaN       NaN
# 17132                                                NaN       NaN       NaN
# 17133                                                NaN       NaN       NaN
# 17134                                                NaN       NaN       NaN
# 17135                                                NaN       NaN       NaN
# 17136                                                NaN       NaN       NaN
# 17137                                                NaN       NaN       NaN
# 17138                                                NaN       NaN       NaN
# 17139                                                NaN       NaN       NaN
# 17140                                                NaN       NaN       NaN
# 17141                                                NaN       NaN       NaN
# 17142                                                NaN       NaN       NaN
# 17143                                                NaN       NaN       NaN
# 17144                                                NaN       NaN       NaN
# 17145                                                NaN       NaN       NaN
# 17146                                                NaN       NaN       NaN
# 17147                                                NaN       NaN       NaN
# 17148                                                NaN       NaN       NaN
# 17149                                                NaN       NaN       NaN
# 17150                                                NaN       NaN       NaN
# 17151                                                NaN       NaN       NaN
# 17152                                                NaN       NaN       NaN
# 17153                                                NaN       NaN       NaN
# 17154                                                NaN       NaN       NaN
# 17155                                                NaN       NaN       NaN
# 17156                                                NaN       NaN       NaN
# 17157                                                NaN       NaN       NaN
#
# [17158 rows x 17 columns]

# %%
dbpedia_chem_data.to_csv('dbpedia_chem_data.csv')

# %%
dbpedia_chem_data.count()
# Out:
# c                         17158
# label                     17139
# stdinchikey                4315
# stdinchi                   4320
# smiles                     4913
# fdaUniiCode                3445
# chembl                     3066
# wikidata                  16850
# routesOfAdministration     2553
# pubchem                    4886
# casNumber                  5197
# kegg                       2201
# iupharLigand               1416
# chemspiderid               5200
# synonyms                    880
# atcPrefix                  4740
# atcSuffix                  2727
# dtype: int64

# %%
missing_wd = dbpedia_chem_data.loc[pd.isnull(dbpedia_chem_data['wikidata'].values), 'c']

print(len(missing_wd_df))
for x in missing_wd:
    print(x)
# Out:
# 308
# http://dbpedia.org/resource/Norepinephrine_(medication)
# http://dbpedia.org/resource/Hydroxyprogesterone_heptanoate
# http://dbpedia.org/resource/Bismuth_subcitrate/metronidazole/tetracycline
# http://dbpedia.org/resource/Rimeporide
# http://dbpedia.org/resource/NBOMe-mescaline
# http://dbpedia.org/resource/Ixazomib
# http://dbpedia.org/resource/Phenylpiracetam_hydrazide
# http://dbpedia.org/resource/Saracatinib
# http://dbpedia.org/resource/3',4'-Dimethoxy-α-pyrrolidinopentiophenone
# http://dbpedia.org/resource/Dimethylaminopivalophenone
# http://dbpedia.org/resource/Nifoxipam
# http://dbpedia.org/resource/4-Fluoromethylphenidate
# http://dbpedia.org/resource/Deschloroketamine
# http://dbpedia.org/resource/Para-Chloromethamphetamine
# http://dbpedia.org/resource/5F-NNE1
# http://dbpedia.org/resource/THJ-018
# http://dbpedia.org/resource/AMB-CHMINACA
# http://dbpedia.org/resource/BIM-018
# http://dbpedia.org/resource/FDU-PB-22
# http://dbpedia.org/resource/FUB-144
# http://dbpedia.org/resource/PX-1
# http://dbpedia.org/resource/PX-2
# http://dbpedia.org/resource/SDB-005
# http://dbpedia.org/resource/1-(3-chlorophenyl)-4-(2-phenylethyl)piperazine
# http://dbpedia.org/resource/4'-Methoxy-α-Pyrrolidinopentiophenone
# http://dbpedia.org/resource/2-Phenyl-3-aminobutane
# http://dbpedia.org/resource/CRL-40,940
# http://dbpedia.org/resource/Desmethyletizolam
# http://dbpedia.org/resource/Propylphenidate
# http://dbpedia.org/resource/Clonazolam
# http://dbpedia.org/resource/FUB-PB-22
# http://dbpedia.org/resource/PTI-1
# http://dbpedia.org/resource/PTI-2
# http://dbpedia.org/resource/4-Chloromethcathinone
# http://dbpedia.org/resource/Omarigliptin
# http://dbpedia.org/resource/Methamnetamine
# http://dbpedia.org/resource/5F-AB-FUPPYCA
# http://dbpedia.org/resource/5F-EMB-PINACA
# http://dbpedia.org/resource/5F-PCN
# http://dbpedia.org/resource/ADAMANTYL-THPINACA
# http://dbpedia.org/resource/FAB-144
# http://dbpedia.org/resource/FDU-NNE1
# http://dbpedia.org/resource/FUB-APINACA
# http://dbpedia.org/resource/MDMB-FUBICA
# http://dbpedia.org/resource/AB-CHMFUPPYCA
# http://dbpedia.org/resource/Ipragliflozin
# http://dbpedia.org/resource/Trelagliptin
# http://dbpedia.org/resource/VT-464
# http://dbpedia.org/resource/Apalutamide
# http://dbpedia.org/resource/Retroprogesterone
# http://dbpedia.org/resource/Pregna-4,20-dien-3,6-dione
# http://dbpedia.org/resource/Emicerfont
# http://dbpedia.org/resource/Setipiprant
# http://dbpedia.org/resource/Ulimorelin
# http://dbpedia.org/resource/Vosoritide
# http://dbpedia.org/resource/Topilutamide
# http://dbpedia.org/resource/Norgestomet
# http://dbpedia.org/resource/Norgesterone
# http://dbpedia.org/resource/Etelcalcetide
# http://dbpedia.org/resource/Gardiquimod
# http://dbpedia.org/resource/Ceftazidime/avibactam
# http://dbpedia.org/resource/13-Hydroxyoctadecadienoic_acid
# http://dbpedia.org/resource/2,2,3,3-Tetramethylsuccinic_acid
# http://dbpedia.org/resource/2,4,5-Trihydroxyamphetamine
# http://dbpedia.org/resource/2-Methylnaphthalene
# http://dbpedia.org/resource/2-Oxohistidine
# http://dbpedia.org/resource/3,3,4,4-Tetramethyltetrahydrofuran
# http://dbpedia.org/resource/3,3,4,4-Tetramethyltetrahydrofuran-2,5-dione
# http://dbpedia.org/resource/3-Amino-9-ethylcarbazole
# http://dbpedia.org/resource/3C-DFE
# http://dbpedia.org/resource/5-Formyluracil
# http://dbpedia.org/resource/5-Hydroxycytosine
# http://dbpedia.org/resource/5-Hydroxyhydantoin
# http://dbpedia.org/resource/5-Hydroxyuracil
# http://dbpedia.org/resource/5β-Dihydroprogesterone
# http://dbpedia.org/resource/Cyanidin-3,5-O-diglucoside
# http://dbpedia.org/resource/Cytosine_glycol
# http://dbpedia.org/resource/Dihydrotetrabenazine
# http://dbpedia.org/resource/Dimethyldiborane
# http://dbpedia.org/resource/Epipregnanolone
# http://dbpedia.org/resource/Helenin
# http://dbpedia.org/resource/Lumacaftor/ivacaftor
# http://dbpedia.org/resource/MRK-016
# http://dbpedia.org/resource/Methyl_lactate
# http://dbpedia.org/resource/Methyldiborane
# http://dbpedia.org/resource/Parathion_methyl
# http://dbpedia.org/resource/Perfluorotoluene
# http://dbpedia.org/resource/Pivaldehyde
# http://dbpedia.org/resource/Propadienone
# http://dbpedia.org/resource/Propynal
# http://dbpedia.org/resource/Thymine_glycol
# http://dbpedia.org/resource/Trimethyldiborane
# http://dbpedia.org/resource/Uracil_glycol
# http://dbpedia.org/resource/1,1,1-Tribromoethane
# http://dbpedia.org/resource/1,3-Dichlorobenzene
# http://dbpedia.org/resource/1,3-Diisocyanatobenzene
# http://dbpedia.org/resource/1,4-Dichloro-2-nitrobenzene
# http://dbpedia.org/resource/1,6-Methano(10)annulene
# http://dbpedia.org/resource/1-Hydroxypyrene
# http://dbpedia.org/resource/2,2,5,5-Tetramethyltetrahydrofuran
# http://dbpedia.org/resource/2,5-Dichloroaniline
# http://dbpedia.org/resource/2-Butoxyethanol_acetate
# http://dbpedia.org/resource/2-Hydroxyazulene
# http://dbpedia.org/resource/20-Hydroxyeicosatetraenoic_acid
# http://dbpedia.org/resource/3,4-Dimethoxystyrene
# http://dbpedia.org/resource/3-Methylfuran
# http://dbpedia.org/resource/3α-Dihydroprogesterone
# http://dbpedia.org/resource/3β-Dihydroprogesterone
# http://dbpedia.org/resource/4,4′-Diamino-2,2′-stilbenedisulfonic_acid
# http://dbpedia.org/resource/4-Oxo-2-nonenal
# http://dbpedia.org/resource/6,14-Endoethenotetrahydrooripavine
# http://dbpedia.org/resource/9-Hydroxyoctadecadienoic_acid
# http://dbpedia.org/resource/Benzocyclooctatetraene
# http://dbpedia.org/resource/Calicene
# http://dbpedia.org/resource/Californium(III)_polyborate
# http://dbpedia.org/resource/Cyclobutanone
# http://dbpedia.org/resource/Cyclohexadecaoctaene
# http://dbpedia.org/resource/Cyclononatetraene
# http://dbpedia.org/resource/Cyclopentadienone
# http://dbpedia.org/resource/Cyclopentyl_methyl_ether
# http://dbpedia.org/resource/Cyclopropenone
# http://dbpedia.org/resource/Diapocynin
# http://dbpedia.org/resource/Dibromine_trioxide
# http://dbpedia.org/resource/Dihydrotanshinone
# http://dbpedia.org/resource/Ferbam
# http://dbpedia.org/resource/Fluopyram
# http://dbpedia.org/resource/Ideain
# http://dbpedia.org/resource/Imidazolate
# http://dbpedia.org/resource/Irganox_1098
# http://dbpedia.org/resource/Jiadifenolide
# http://dbpedia.org/resource/Myxoxanthophyll
# http://dbpedia.org/resource/N-Sulfinylaniline
# http://dbpedia.org/resource/Oligopetide_P11-4
# http://dbpedia.org/resource/Pachymic_acid
# http://dbpedia.org/resource/Pelargonin
# http://dbpedia.org/resource/Pentaheptafulvalene
# http://dbpedia.org/resource/Perfluorocyclohexane
# http://dbpedia.org/resource/Phosphoramide
# http://dbpedia.org/resource/Salicyl_alcohol
# http://dbpedia.org/resource/Sandalore
# http://dbpedia.org/resource/Sodium_triethylborohydride
# http://dbpedia.org/resource/Tetrahydroxy-1,2-benzoquinone
# http://dbpedia.org/resource/Tetramethyldiborane
# http://dbpedia.org/resource/Triafulvalene
# http://dbpedia.org/resource/Vanadium_phosphate
# http://dbpedia.org/resource/RVX_208
# http://dbpedia.org/resource/Triisopropanolamine
# http://dbpedia.org/resource/Remazol_Brilliant_Blue_R
# http://dbpedia.org/resource/Serlopitant
# http://dbpedia.org/resource/Viridin
# http://dbpedia.org/resource/Lespedamine
# http://dbpedia.org/resource/Strictosidine
# http://dbpedia.org/resource/Galanin__1
# http://dbpedia.org/resource/Neurotensin__1
# http://dbpedia.org/resource/Apiole
# http://dbpedia.org/resource/Ralpancizumab
# http://dbpedia.org/resource/3-Hydroxy-16-methoxy-2,3-dihydrotabersonine
# http://dbpedia.org/resource/Thienorphine
# http://dbpedia.org/resource/Mercury(I)_fluoride
# http://dbpedia.org/resource/LGD-4033
# http://dbpedia.org/resource/AN2728
# http://dbpedia.org/resource/Hentriacontanonaene
# http://dbpedia.org/resource/Tarextumab
# http://dbpedia.org/resource/Tabersonine
# http://dbpedia.org/resource/Thorium_oxalate
# http://dbpedia.org/resource/Rinucumab
# http://dbpedia.org/resource/Niobium_pentaiodide
# http://dbpedia.org/resource/Synthane
# http://dbpedia.org/resource/2,4,5-Trimethoxyphenethylamine
# http://dbpedia.org/resource/Tetramethyl_acetyloctahydronaphthalenes
# http://dbpedia.org/resource/Platinum_fulminate
# http://dbpedia.org/resource/Rigosertib
# http://dbpedia.org/resource/Sedanolide
# http://dbpedia.org/resource/Corticotropin-like_intermediate_peptide__L-arginyl-L-prolyl-L-valyl-L-lysyl-L-valyl-L-tyros__1
# http://dbpedia.org/resource/Difluorophosphate
# http://dbpedia.org/resource/Drimane
# http://dbpedia.org/resource/Triphenylphosphine_selenide
# http://dbpedia.org/resource/Glucagon__1
# http://dbpedia.org/resource/Human_chorionic_gonadotropin__1
# http://dbpedia.org/resource/Substance_P__1
# http://dbpedia.org/resource/Thyrotropin-releasing_hormone__1
# http://dbpedia.org/resource/Alpha-1_antitrypsin__Alpha-1-proteinase_inhibitor__1
# http://dbpedia.org/resource/Melanocyte-stimulating_hormone__1
# http://dbpedia.org/resource/Dichlorophen
# http://dbpedia.org/resource/Selurampanel
# http://dbpedia.org/resource/Tilapertin
# http://dbpedia.org/resource/Tipiracil
# http://dbpedia.org/resource/Alpha-Pyrrolidinohexiophenone
# http://dbpedia.org/resource/Refanezumab
# http://dbpedia.org/resource/Prostvac
# http://dbpedia.org/resource/Nepetalactol
# http://dbpedia.org/resource/Tantalum_pentaiodide
# http://dbpedia.org/resource/Preakuammicine
# http://dbpedia.org/resource/Bismoclite
# http://dbpedia.org/resource/Hexaphenylethane
# http://dbpedia.org/resource/SRX246
# http://dbpedia.org/resource/Benzoxepin
# http://dbpedia.org/resource/Interferon_gamma__Human_interferon_gamma-1b__1
# http://dbpedia.org/resource/Vofopitant
# http://dbpedia.org/resource/Roflurane
# http://dbpedia.org/resource/16-Methoxytabersonine
# http://dbpedia.org/resource/Tetracalcium_phosphate
# http://dbpedia.org/resource/Trimethylhexamethylenediamine
# http://dbpedia.org/resource/Verucerfont
# http://dbpedia.org/resource/Atrop-abyssomicin_C
# http://dbpedia.org/resource/Methylselenocysteine
# http://dbpedia.org/resource/Trengestone
# http://dbpedia.org/resource/Losoxantrone
# http://dbpedia.org/resource/Setmelanotide
# http://dbpedia.org/resource/MEAI
# http://dbpedia.org/resource/ACH-3102
# http://dbpedia.org/resource/Metacinnabar
# http://dbpedia.org/resource/Curacin_A
# http://dbpedia.org/resource/Methyltrimethoxysilane
# http://dbpedia.org/resource/Examorelin
# http://dbpedia.org/resource/Isopropylphenidate
# http://dbpedia.org/resource/PIDA_(polymer)
# http://dbpedia.org/resource/Ruthenium_pentafluoride
# http://dbpedia.org/resource/ITI-007
# http://dbpedia.org/resource/Testosterone_isocaproate
# http://dbpedia.org/resource/2-Methylimidazole
# http://dbpedia.org/resource/Remeglurant
# http://dbpedia.org/resource/Nitroapocynin
# http://dbpedia.org/resource/Gramicidin__changed__1
# http://dbpedia.org/resource/Granulocyte_macrophage_colony-stimulating_factor__Human_granulocyte_macrophage_colony_stimulating_fa__1
# http://dbpedia.org/resource/LY-156,735
# http://dbpedia.org/resource/Nylon_12
# http://dbpedia.org/resource/Caffeic_aldehyde
# http://dbpedia.org/resource/Hyaluronidase__hyaluronidase__1
# http://dbpedia.org/resource/Mannitol__Mannitol__1
# http://dbpedia.org/resource/Melittin__1
# http://dbpedia.org/resource/Neuropeptide_Y__1
# http://dbpedia.org/resource/Norstictic_acid
# http://dbpedia.org/resource/Neurokinin_A__1
# http://dbpedia.org/resource/MN-18
# http://dbpedia.org/resource/Pigment_yellow_139
# http://dbpedia.org/resource/Magnesium_monohydride
# http://dbpedia.org/resource/Monofluorophosphate
# http://dbpedia.org/resource/4-Chlorokynurenine
# http://dbpedia.org/resource/5-IT
# http://dbpedia.org/resource/Ralfinamide
# http://dbpedia.org/resource/Teflurane
# http://dbpedia.org/resource/Zonampanel
# http://dbpedia.org/resource/RTA_408
# http://dbpedia.org/resource/4-Bromomethcathinone
# http://dbpedia.org/resource/THJ-2201
# http://dbpedia.org/resource/PX-3
# http://dbpedia.org/resource/Quinfamide
# http://dbpedia.org/resource/Relamorelin
# http://dbpedia.org/resource/Quinestradol
# http://dbpedia.org/resource/SB-236057
# http://dbpedia.org/resource/SCH-202,596
# http://dbpedia.org/resource/Penicillin_O
# http://dbpedia.org/resource/Silver_diamine_fluoride
# http://dbpedia.org/resource/FMISO
# http://dbpedia.org/resource/AI-10-49
# http://dbpedia.org/resource/N-2′-Indolylnaltrexamine
# http://dbpedia.org/resource/Pisatin
# http://dbpedia.org/resource/Onnamide_A
# http://dbpedia.org/resource/2-Azetidinone
# http://dbpedia.org/resource/Pelretin
# http://dbpedia.org/resource/12-Hydroxyheptadecatrienoic_acid
# http://dbpedia.org/resource/3'-Hydroxyechinenone
# http://dbpedia.org/resource/Echinenone
# http://dbpedia.org/resource/Nylon_46
# http://dbpedia.org/resource/PyAOP_reagent
# http://dbpedia.org/resource/Talmessite
# http://dbpedia.org/resource/Taxadienone
# http://dbpedia.org/resource/Ambroxide
# http://dbpedia.org/resource/Chymopapain__1
# http://dbpedia.org/resource/Raseglurant
# http://dbpedia.org/resource/Selepressin
# http://dbpedia.org/resource/WB-4101
# http://dbpedia.org/resource/Radalbuvir
# http://dbpedia.org/resource/Ripasudil
# http://dbpedia.org/resource/Sofituzumab_vedotin
# http://dbpedia.org/resource/Varlilumab
# http://dbpedia.org/resource/Pralmorelin
# http://dbpedia.org/resource/Samatasvir
# http://dbpedia.org/resource/Platinum_tetrafluoride
# http://dbpedia.org/resource/Stemmadenine
# http://dbpedia.org/resource/Iridodial
# http://dbpedia.org/resource/Reidite
# http://dbpedia.org/resource/15-Hydroxyicosatetraenoic_acid
# http://dbpedia.org/resource/Methylene_cyclopropyl_acetic_acid
# http://dbpedia.org/resource/Benzyl_potassium
# http://dbpedia.org/resource/Pigment_yellow_185
# http://dbpedia.org/resource/Topaquinone
# http://dbpedia.org/resource/Bisacurone
# http://dbpedia.org/resource/Kovdorskite
# http://dbpedia.org/resource/Platinum_pentafluoride
# http://dbpedia.org/resource/RB-64
# http://dbpedia.org/resource/Trifluridine/tipiracil
# http://dbpedia.org/resource/RP5063
# http://dbpedia.org/resource/Nitrogen_monosulfide
# http://dbpedia.org/resource/Ulocuplumab
# http://dbpedia.org/resource/Fluorodeoxyglycosylamine
# http://dbpedia.org/resource/Perdesonide
# http://dbpedia.org/resource/Quinoxalinedione
# http://dbpedia.org/resource/Stenusin
# http://dbpedia.org/resource/Dysidenin
# http://dbpedia.org/resource/Lipid_II
# http://dbpedia.org/resource/Molybdenum_ditelluride
# http://dbpedia.org/resource/Thioacetone
# http://dbpedia.org/resource/2,4-Bis(4-hydroxybenzyl)phenol
# http://dbpedia.org/resource/Uroguanylin__Stereo,_skeletal_formula_of_uroguanylin__1
# http://dbpedia.org/resource/Triazavirin
# http://dbpedia.org/resource/Vanadyl_perchlorate
