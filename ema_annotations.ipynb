# %%
# A notebook for extracting indications from EMA data

# %%
import pandas as pd
import wikidataintegrator as wdi

# %%
ema_data_path = './ema_data/EMA_drugs.csv'
ema_data = pd.read_csv(ema_data_path)
ema_data.head()
# Out:
#                     Medicine Name   Product Number        Active Substance  \
# 0  Abasaglar (previously Abasria)  EMEA/H/C/002835        insulin glargine
# 1                         Abilify  EMEA/H/C/000471            aripiprazole
# 2                Abilify Maintena  EMEA/H/C/002755            aripiprazole
# 3   Ablavar (previously Vasovist)  EMEA/H/C/000601  gadofosveset trisodium
# 4                        Abraxane  EMEA/H/C/000778              paclitaxel
#
#               Common name Atc code      Marketing Authorisation Holder  \
# 0        insulin glargine  A10AE04  Eli Lilly Regional Operations GmbH
# 1            aripiprazole  N05AX12    Otsuka Pharmaceutical Europe Ltd
# 2            aripiprazole  N05AX12    Otsuka Pharmaceutical Europe Ltd
# 3  gadofosveset trisodium    V08CA          TMC Pharma Services Ltd.\n
# 4              paclitaxel  L01CD01               Celgene Europe Ltd\n
#
#        Status  Revision number Authorisation date  \
# 0  Authorised                4         09/09/2014
# 1  Authorised               39         04/06/2004
# 2  Authorised               10         15/11/2013
# 3   Withdrawn               10         03/10/2005
# 4  Authorised               19         11/01/2008
#
#                                           Indication Condition Approval  \
# 0  Treatment of diabetes mellitus in adults, adol...                 no
# 1  Abilify is indicated for the treatment of schi...                 no
# 2  Maintenance treatment of schizophrenia in adul...                 no
# 3  This medicinal product is for diagnostic use o...                 no
# 4  Abraxane monotherapy is indicated for the trea...                 no
#
#   Exceptional Circumstance Is Orphan Is Generic Biosimilar
# 0                       no        no         no        yes
# 1                       no        no         no         no
# 2                       no        no         no         no
# 3                       no        no         no         no
# 4                       no        no         no         no

# %% [markdown]
# TODO: Data needs to be filtered for everything which is not an EMA authorized drug, at some point, but the info that a certain compound has been e.g. withdrawn is interesting for Wikidata and repurposing applications

# %% [markdown]
# ## Get labels and aliases for drugs/compounds and disease

# %%
drug_query = '''
SELECT * WHERE {
    # ?compound wdt:P2275 ?who_name FILTER (LANG(?who_name) = "en") .  
}
'''

# http://tinyurl.com/z6397rh
drug_query = '''
SELECT ?compound ?label ?who_name (GROUP_CONCAT(DISTINCT(?alias); separator="|") AS ?aliases) WHERE {{
  {{?compound wdt:P31 wd:Q11173 .}} UNION  # chemical compound
  {{?compound wdt:P31 wd:Q12140 .}} UNION  # pharmaceutical drug
  {{?compound wdt:P31 wd:Q79529 .}} UNION  # chemical substance
  {{?compound wdt:P2275 ?who_name FILTER (LANG(?who_name) = "en") .}}
  
  OPTIONAL {{
    # ?compound rdfs:label ?label FILTER (LANG(?label) = "en") .
  }}
  OPTIONAL {{
    # ?compound skos:altLabel ?alias FILTER (LANG(?alias) = "en") .
  }}
}}
GROUP BY ?compound ?label ?who_name ?aliases
OFFSET {0}
LIMIT 100000
'''


drug_qid_map = {}

cc = 0
while True:
    r = wdi.wdi_core.WDItemEngine.execute_sparql_query(query=drug_query.format(100000 * cc))
    cc += 1
    
    if len(r['results']['bindings']) == 0:
        break
    
    for x in r['results']['bindings']:
        qid = x['compound']['value']
        
        if 'who_name' in x:
            drug_qid_map.update({x['who_name']['value'].lower(): qid})
            
        if 'label' in x:
            drug_qid_map.update({x['label']['value'].lower(): qid})
            
        if 'aliases' in x:
            drug_qid_map.update({y.lower(): qid for y in x['aliases']['value'].split('|')})
            
        count += 1
            
print('Drug to QID map has {} entries!'.format(len(drug_qid_map)))

no_match_count = 0
combo_drug_count = 0
for count, line in ema_data.iterrows():
#     print(count, line)
    ema_name = line['Common name']
    
    if not all([y in drug_qid_map for y in ema_name.lower().split(' / ')]):
        print(ema_name, count)
        no_match_count += 1
    
    if ' / ' in ema_name:
        combo_drug_count += 1 
        
print(no_match_count, 'did not match')
print(combo_drug_count, 'combination drugs detected')
# Out:
# 274072
# insulin human (rDNA) 12
# human insulin(rDNA) 13
# pandemic influenza vaccine (H5N1) (split virion, inactivated, adjuvanted) 19
# octocog alfa 22
# prepandemic influenza vaccine (H5N1) (surface antigen, inactivated, adjuvanted) 27
# eftrenonacog alfa 39
# hepatitis-A (inactivated) and hepatitis-B (rDNA) (HAB) vaccine (adsorbed) 41
# 5-aminolevulinic acid hydrochloride 42
# pandemic influenza vaccine (H1N1) (split virion, inactivated, adjuvanted) 53
# antithrombin alfa 65
# nonacog alfa 81
# tasonermin 84
# meningococcal group-B vaccine (rDNA, component, adsorbed) 87
# epoetin theta 92
# sugammadex 103
# aclidinium / formoterol fumarate dihydrate 105
# budesonide / formoterol fumarate dihydrate 112
# influenza vaccine (H1N1)v (whole virion, inactivated, prepared in cell culture) 131
# human protein C 133
# human papillomavirus vaccine [types 16, 18] (recombinant, adjuvanted, adsorbed) 136
# characterised viable autologous cartilage cells expanded ex vivo expressing specific marker proteins 141
# reslizumab 147
# C1 inhibitor (human) 148
# human coagulation factor X 176
# colistimethate sodium 178
# copper (64Cu) chloride 197
# betaine anhydrous 201
# mercaptamine bitartrate 202
# amlodipine/ valsartan 204
# Pandemic influenza vaccine (H5N1) (whole virion, inactivated, adsorbed) 209
# ioflupane (123l) 212
# oestrogens conjugated / bazedoxifene 235
# cholera vaccine (inactivated, oral) 236
# epoetin delta 246
# dodecafluoropentane 252
# efmoroctocog alfa 266
# corifollitropin alfa 267
# lutetium (177 Lu) chloride 275
# pancreas powder 284
# birch bark extract 287
# epoetin theta 290
# piperaquine tetraphosphate / dihydroartemisinin 297
# human fibrinogen / human thrombin 298
# human fibrinogen / human thrombin 299
# hepatitisB (rDNA) vaccine (adjuvanted, adsorbed) 322
# ferric citrate coordination complex 326
# human normal immunoglobulin 332
# influenza vaccine (intranasal, live attenuated) 334
# influenza vaccine (live attenuated, nasal) 335
# influenza vaccine (H1N1) (surface antigen, inactivated, adjuvanted) 336
# pandemic influenza vaccine (H5N1) (surface antigen, inactivated, adjuvanted) 337
# recombinant salmon calcitonin 339
# human papillomavirus vaccine [types 6, 11, 16, 18] (recombinant, adsorbed) 351
# human papillomavirus 9-valent vaccine (recombinant, adsorbed) 352
# 5-aminolevulinic acid hydrochloride 360
# alipogene tiparvovec 364
# ledispavir 90 mg / sofosbuvir 400 mg 371
# hepatitis-B vaccine (rDNA) 372
# octocog alfa 374
# triple antigen hepatitis B vaccine (recombinant) 376
# human heterologous liver cells 377
# adefovir dipivoxil 378
# diphtheria, tetanus, pertussis (acellular, component), hepatitis B (rDNA), poliomyelitis (inactivated) and Haemophilus influenzae type-b conjugate vaccine (adsorbed) 381
# diphtheria, tetanus, acellular pertussis, inactivated poliomyelitis, hepatitisB (recombinant) and Haemophilus influenzae type b conjugate vaccine, adjuvanted 382
# diphtheria, tetanus, pertussis (acellular, component), hepatitis B (rDNA), poliomyelitis (inactivated) and Haemophilus influenzae type-b conjugate vaccine (adsorbed) 383
# human normal immunoglobulin (SCIg) 385
# ex vivo expanded autologous human corneal epithelial cells containing stem cells 386
# pandemic influenza vaccine (H1N1, split virion, inactivated, adjuvanted) 389
# human normal immunoglobulin 392
# octocog alfa 397
# albutrepenonacog alfa 401
# influenza vaccine (split virion, inactivated) 402
# human hepatitis B immunoglobulin 413
# modified vaccinia Ankara virus 418
# igovomab 423
# dibotermin alfa 424
# diphtheria, tetanus, acellular pertussis and hepatitis B recombinant, adsorbed vaccine 425
# diphtheria (D), tetanus (T), pertussis (acellular, component) (Pa), hepatitis B (rDNA) (HBV), poliomyelitis (inactivated) (IPV) and Haemophilus influenzae type-b (Hib) conjugate vaccine (adsorbed) 426
# diphtheria, tetanus, pertussis (acellular, component), hepatitis-B (rDNA) andpoliomyelitis (inactivated)vaccine (adsorbed) 427
# insulin human (rDNA) 435
# influenza vaccine (split virion, inactivated) 438
# canagliflozin 447
# Japanese-encephalitis vaccine (inactivated, adsorbed) 465
# levetiracetam 486
# human normal immunoglobulin 493
# octocog alfa 496
# octocog alfa 499
# sulesomab 519
# levetiracetam 521
# levetiracetam 522
# levetiracetam 523
# levetiracetam 524
# levetiracetam 525
# levetiracetam 526
# levetiracetam 527
# lipegfilgrastim 538
# lutetium, isotope of mass 177 542
# tilmanocept 546
# dasiprotimut-t 547
# measles, mumps and rubella vaccine (live) 552
# matrix-applied characterised autologous cultured chondrocytes 555
# levetiracetam 560
# meningococcal group A, C, W-135 and Y conjugate vaccine 567
# insulin human (rDNA) 578
# insulin human (rDNA) 580
# epoetin beta 599
# florbetaben(18F) 607
# concentrate of proteolytic enzymes enriched in bromelain 613
# meningococcal group A, C, W 135 and Y conjugate vaccine 614
# human coagulation factor IX 619
# eptacog alfa (activated) 626
# simoctocog alfa (rFVIII) 635
# susoctocog alfa 637
# eptotermin alfa 663
# influenza vaccine (surface antigen, inactivated, prepared in cell cultures) 666
# eptotermin alfa 678
# pandemic influenza vaccine (H5N1) (whole virion, inactivated, prepared in cell culture) 688
# pandemic influenza vaccine (H5N1) (live attenuated, nasal) 689
# influenza vaccine (H1N1)v (split virion, inactivated, adjuvanted) A/California/7/2009 (H1N1)v like strain (x-179a) 690
# porfimer sodium 714
# parathyroid hormone (rDNA) 743
# prepandemic influenza vaccine (H5N1) (split virion, inactivated, adjuvanted) 744
# prepandemic influenza vaccine (H5N1) (surface antigen, inactivated, adjuvanted) 745
# prepandemic influenza vaccine (H5N1) (split virion, inactivated, adjuvanted) 746
# pneumococcal saccharide conjugated vaccine, adsorbed 747
# pneumococcal polysaccharide conjugate vaccine (13-valent, adsorbed) 748
# diphtheria, tetanus and hepatitis B vaccine, adsorbed 751
# human normal immunoglobulin (IVIg) 754
# haemophilusB conjugate (meningococcal protein conjugate) and hepatitis B (recombinant) vaccine 755
# measles, mumps, rubella and varicella vaccine (live) 760
# insulin human (rDNA) 761
# autologous peripheral-blood mononuclear cells activated with prostatic acid phosphatase granulocyte-macrophage colony-stimulating factor (sipuleucel-T) 765
# pandemic influenza vaccine (H5N1) (split virion, inactivated, adjuvanted) 766
# samarium [153Sm] lexidronam pentasodium 772
# diphtheria, tetanus, pertussis (whole cell), hepatitis B (rDNA) and Haemophilus influenzae typeB conjugate vaccine (absorbed) 774
# human fibrinogen / human thrombin 782
# moroctocog alfa 797
# sevelamer carbonate 806
# human alpha1-proteinase inhibitor 814
# desirudin 816
# atazanavir sulphate 822
# ferumoxytol 829
# nonacog gamma 844
# rotavirus vaccine, live, attenuated 846
# rotavirus vaccine, attenuated 847
# rotavirus vaccine, live 848
# insulin degludec / insulin aspart 850
# sevelamer carbonate 863
# glycopyrronium 864
# human papillomavirus vaccine [types 6, 11, 16, 18] (recombinant, adsorbed) 872
# bosentan monohydrate 895
# autologous CD34+ enriched cell fraction that contains CD34+ cells transduced with retroviral vector that encodes for the human ADA cDNA sequence 901
# pneumococcal polysaccharide conjugate vaccine (adsorbed) 909
# human fibrinogen / human thrombin 911
# sevelamer hydrochloride 921
# anti-melanoma mab fragments 927
# yttrium [90Y] chloride 949
# laropiprant/ nicotinic acid 973
# insulin degludec 974
# combined diphtheria, tetanus and acellular pertussis vaccine 977
# diphtheria, tetanus, pertussis (whole cell) and hepatitis-B (rDNA)vaccine (adsorbed) 979
# abacavir (as sulfate) / lamivudine / zidovudine 981
# hepatitisA (inactivated) and hepatitis B (rDNA) (HAB) vaccine (adsorbed) 991
# hepatitis-A (inactivated) and hepatitis-B (rDNA) (HAB) vaccine (adsorbed) 992
# insulin human (rDNA) 999
# diphtheria, tetanus, pertussis (acellular, component), hepatitis B (rDNA), poliomyelitis (inactivated) and Haemophilus type b conjugate vaccine (adsorbed) 1014
# insulin human (rDNA) 1019
# mixture of polynuclear iron(III)-oxyhydroxide, sucrose and starches 1020
# Prepandemic influenza vaccine (H5N1) (whole virion, inactivated,prepared in cell culture) 1024
# flutemetamol (18F) 1047
# canagliflozin / metformin 1049
# human coagulation factor VIII / human von willebrand factor 1051
# mercaptopurine 1064
# drotrecogin alfa (activated) 1076
# radium Ra223 dichloride 1078
# insulin degludec / liraglutide 1082
# yttrium [90Y] chloride 1090
# yttrium [90Y] chloride 1091
# allogeneic T cells genetically modified with a retroviral vector encoding for a truncated form of the human low affinity nerve growth factor receptor (LNGFR) and the herpes simplex I virus thymidine kinase (HSV-TK Mut2) 1093
# elbasvir / grazoprevir 1106
# zoster vaccine (live) 1129
# human hepatitis-B immunoglobulin 1131
# 182 did not match
# 134 combination drugs detected

# %%
print(len(drug_qid_map))
drug_qid_map['besilesomab']
# Out:
# 274072
# 'http://www.wikidata.org/entity/Q1871058'

# %%
disease_query = '''
SELECT ?disease ?label (GROUP_CONCAT(DISTINCT(?alias); separator="|") AS ?aliases) WHERE { 
  {?disease wdt:P486 ?mesh .} UNION  # Mesh
  {?disease wdt:P699 ?doid .} UNION  # DO
  {?disease wdt:P494 wd:Q11173 .} MINUS  # ICD-10
  {?disease wdt:P31 wd:Q11173 .} 
  
  OPTIONAL {
    # ?disease rdfs:label ?label FILTER (LANG(?label) = "en") .
  }
  OPTIONAL {
    # ?disease skos:altLabel ?alias FILTER (LANG(?alias) = "en") .
  }
}
GROUP BY ?disease ?label ?aliases
'''

indication_keywords = ['is indicated']
